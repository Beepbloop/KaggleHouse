# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
for dirname, _, filenames in os.walk('../../Datas/KaggleHouse/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ../../Datas/KaggleHouse/data_description.txt
# ../../Datas/KaggleHouse/house-prices-advanced-regression-techniques.zip
# ../../Datas/KaggleHouse/Id.csv
# ../../Datas/KaggleHouse/sample_submission.csv
# ../../Datas/KaggleHouse/test.csv
# ../../Datas/KaggleHouse/train.csv
# ../../Datas/KaggleHouse/X_test_V2.csv
# ../../Datas/KaggleHouse/X_train_V2.csv
# ../../Datas/KaggleHouse/Y_train_V2_log.csv
# ../../Datas/KaggleHouse/Y_train_V2_Nolog.csv

# %%
train = pd.read_csv('../../Datas/KaggleHouse/train.csv')
test = pd.read_csv('../../Datas/KaggleHouse/test.csv')
data_list = [train, test]

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
df = pd.concat(data_list)
df.shape
# Out:
# c:\program files\python35\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# (2919, 81)

# %%
def OCCommon(s):
    if s == 'Ex':
        return 5
    elif s == 'Gd':
        return 4
    elif s == 'TA':
        return 3
    elif s == 'Fa':
        return 2
    elif s == 'Po':
        return 1
    else:
        return 0

def StreetQul(s):
    if s == 'Pave':
        return 2
    elif s == 'Grvl':
        return 1
    else:
        return 0

def LanCon(s):
    if s == 'Lvl':
        return 2
    else:
        return 1

def

# %%
OCC_list = ['ExterQual','ExterCond','BsmtQual','BsmtCond','HeatingQC','KitchenQual','FireplaceQu','GarageQual','GarageCond','PoolQC']
StrQul_list = ['Alley','Street']

# %%
for OCC in OCC_list:
    df[OCC] = df[OCC].apply(OCCommon)

for StrQul in StrQul_list:
    df[StrQul] = df[StrQul].apply(StreetQul)

df['LandContour']=df['LandContour'].apply(LanCon)

# %%
def plotAllHis(df):
    for col in df.columns.to_list():
        print("+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
        try:
            sns.distplot(df[col].dropna(),label=col)
            print(col + " dtype: "+ str(df[col].dtype))
            plt.show()
        except:
            print(col + " Unique: " + str(train[col].unique()))
            print("Num of unique: "+ str(train[col].unique().shape[0]))

# %%
plotAllHis(df)
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 1stFlrSF dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 2ndFlrSF dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 3SsnPorch dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Alley Unique: [nan 'Grvl' 'Pave']
# Num of unique: 3
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BedroomAbvGr dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BldgType Unique: ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# Num of unique: 5
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtCond dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtExposure Unique: ['No' 'Gd' 'Mn' 'Av' nan]
# Num of unique: 5
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtFinSF1 dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtFinSF2 dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtFinType1 Unique: ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' nan 'LwQ']
# Num of unique: 7
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtFinType2 Unique: ['Unf' 'BLQ' nan 'ALQ' 'Rec' 'LwQ' 'GLQ']
# Num of unique: 7
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtFullBath dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtHalfBath dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtQual dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# BsmtUnfSF dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# CentralAir Unique: ['Y' 'N']
# Num of unique: 2
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Condition1 Unique: ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# Num of unique: 9
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Condition2 Unique: ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# Num of unique: 8
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Electrical Unique: ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix' nan]
# Num of unique: 6
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# EnclosedPorch dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ExterCond dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ExterQual dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Exterior1st Unique: ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']
# Num of unique: 15
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Exterior2nd Unique: ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']
# Num of unique: 16
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Fence Unique: [nan 'MnPrv' 'GdWo' 'GdPrv' 'MnWw']
# Num of unique: 5
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# FireplaceQu dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Fireplaces dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Foundation Unique: ['PConc' 'CBlock' 'BrkTil' 'Wood' 'Slab' 'Stone']
# Num of unique: 6
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# FullBath dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Functional Unique: ['Typ' 'Min1' 'Maj1' 'Min2' 'Mod' 'Maj2' 'Sev']
# Num of unique: 7
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GarageArea dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GarageCars dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GarageCond dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GarageFinish Unique: ['RFn' 'Unf' 'Fin' nan]
# Num of unique: 4
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GarageQual dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GarageType Unique: ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' nan 'Basment' '2Types']
# Num of unique: 7
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GarageYrBlt dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# GrLivArea dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# HalfBath dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Heating Unique: ['GasA' 'GasW' 'Grav' 'Wall' 'OthW' 'Floor']
# Num of unique: 6
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# HeatingQC dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# HouseStyle Unique: ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# Num of unique: 8
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Id dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# KitchenAbvGr dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# KitchenQual dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# LandContour Unique: ['Lvl' 'Bnk' 'Low' 'HLS']
# Num of unique: 4
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# LandSlope Unique: ['Gtl' 'Mod' 'Sev']
# Num of unique: 3
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# LotArea dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# LotConfig Unique: ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# Num of unique: 5
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# LotFrontage dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# LotShape Unique: ['Reg' 'IR1' 'IR2' 'IR3']
# Num of unique: 4
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# LowQualFinSF dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# MSSubClass dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# MSZoning Unique: ['RL' 'RM' 'C (all)' 'FV' 'RH']
# Num of unique: 5
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# MasVnrArea dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# MasVnrType Unique: ['BrkFace' 'None' 'Stone' 'BrkCmn' nan]
# Num of unique: 5
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# MiscFeature Unique: [nan 'Shed' 'Gar2' 'Othr' 'TenC']
# Num of unique: 5
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# MiscVal dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# MoSold dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Neighborhood Unique: ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# Num of unique: 25
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# OpenPorchSF dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# OverallCond dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# OverallQual dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# PavedDrive Unique: ['Y' 'N' 'P']
# Num of unique: 3
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# PoolArea dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# PoolQC dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# RoofMatl Unique: ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']
# Num of unique: 8
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# RoofStyle Unique: ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# Num of unique: 6
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# SaleCondition Unique: ['Normal' 'Abnorml' 'Partial' 'AdjLand' 'Alloca' 'Family']
# Num of unique: 6
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# SalePrice dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# SaleType Unique: ['WD' 'New' 'COD' 'ConLD' 'ConLI' 'CWD' 'ConLw' 'Con' 'Oth']
# Num of unique: 9
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ScreenPorch dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Street Unique: ['Pave' 'Grvl']
# Num of unique: 2
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# TotRmsAbvGrd dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# TotalBsmtSF dtype: float64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Utilities Unique: ['AllPub' 'NoSeWa']
# Num of unique: 2
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# WoodDeckSF dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# YearBuilt dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# YearRemodAdd dtype: int64
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# YrSold dtype: int64
